# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN
from tensorflow.keras.utils import to_categorical

warnings.filterwarnings('ignore')

# %%
# !python -m pip show tensorflow

# %%
# import sys
# print(sys.executable)
# !{sys.executable} -m pip install tensorflow

# %%
# print(sklearn.__version__)

# %%
# !pip install -U scikit-learn==1.6.0
# !pip install tensorflow==2.15

# %%
df = pd.read_csv(r"E:\Project\Hari Mini Project\GrowEver\Data\crop_data.csv")

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.size
# Out:
# 17600

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
# sns.heatmap(df.corr(),annot=True)

# %%
df_encoded = df.copy()
for col in df_encoded.select_dtypes(include=['object']):
    df_encoded[col] = LabelEncoder().fit_transform(df_encoded[col])

sns.heatmap(df_encoded.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Seperating features and target label

# %%
features = df[['N', 'P','K','temperature', 'humidity', 'ph', 'rainfall']]
target = df['label']
#features = df[['temperature', 'humidity', 'ph', 'rainfall']]
labels = df['label']

# %%
# Initialzing empty lists to append all model's name and corresponding name
acc = []
models = []

# %%
le = LabelEncoder()
df['label_encoded'] = le.fit_transform(df['label'])

# %%
X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = to_categorical(df['label_encoded'])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Multi-Layer Perceptron

# %%
model_mlp = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# %%
model_mlp.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model_mlp.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2996 - loss: 2.7505 - val_accuracy: 0.6591 - val_loss: 1.5849
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7642 - loss: 1.2656 - val_accuracy: 0.8864 - val_loss: 0.6535
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8807 - loss: 0.5420 - val_accuracy: 0.9261 - val_loss: 0.3875
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9397 - loss: 0.3138 - val_accuracy: 0.9318 - val_loss: 0.2752
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9439 - loss: 0.2260 - val_accuracy: 0.9261 - val_loss: 0.2210
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9548 - loss: 0.1772 - val_accuracy: 0.9432 - val_loss: 0.1791
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9636 - loss: 0.1430 - val_accuracy: 0.9659 - val_loss: 0.1445
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9692 - loss: 0.1189 - val_accuracy: 0.9659 - val_loss: 0.1234
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9761 - loss: 0.1013 - val_accuracy: 0.9602 - val_loss: 0.1233
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9734 - loss: 0.0975 - val_accuracy: 0.9602 - val_loss: 0.1152
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9686 - loss: 0.0886 - val_accuracy: 0.9773 - val_loss: 0.1004
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9837 - loss: 0.0683 - val_accuracy: 0.9716 - val_loss: 0.0978
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9860 - loss: 0.0628 - val_accuracy: 0.9773 - val_loss: 0.0734
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9803 - loss: 0.0553 - val_accuracy: 0.9773 - val_loss: 0.0834
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9851 - loss: 0.0607 - val_accuracy: 0.9716 - val_loss: 0.0728
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9828 - loss: 0.0586 - val_accuracy: 0.9716 - val_loss: 0.0664
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9845 - loss: 0.0514 - val_accuracy: 0.9716 - val_loss: 0.0709
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9904 - loss: 0.0503 - val_accuracy: 0.9830 - val_loss: 0.0548
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9851 - loss: 0.0425 - val_accuracy: 0.9830 - val_loss: 0.0532
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        14
#            8       0.90      0.83      0.86        23
#            9       0.91      1.00      0.95        20
#           10       0.73      1.00      0.85        11
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.88      0.93        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        14
#           17       1.00      1.00      1.00        23
#           18       1.00      0.91      0.95        23
#           19       1.00      1.00      1.00        23
#           20       0.81      0.89      0.85        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.97       440
#    macro avg       0.97      0.98      0.97       440
# weighted avg       0.98      0.97      0.97       440

# %%
# model_mlp.save('../models/MLP.h5')

# %% [markdown]
# # LSTM

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_reshaped = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=42)

# %%
model_lstm = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# %%
model_lstm.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.1140 - loss: 2.9571 - val_accuracy: 0.2159 - val_loss: 2.2345
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2786 - loss: 2.0082 - val_accuracy: 0.5057 - val_loss: 1.3627
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5419 - loss: 1.2814 - val_accuracy: 0.5341 - val_loss: 1.0870
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6460 - loss: 0.9890 - val_accuracy: 0.7386 - val_loss: 0.8338
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7302 - loss: 0.7900 - val_accuracy: 0.8125 - val_loss: 0.6700
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7868 - loss: 0.6341 - val_accuracy: 0.8239 - val_loss: 0.5242
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8303 - loss: 0.5209 - val_accuracy: 0.8807 - val_loss: 0.4680
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8616 - loss: 0.4463 - val_accuracy: 0.8920 - val_loss: 0.4245
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8949 - loss: 0.3532 - val_accuracy: 0.9148 - val_loss: 0.2852
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9179 - loss: 0.2798 - val_accuracy: 0.9375 - val_loss: 0.2386
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9209 - loss: 0.2493 - val_accuracy: 0.9205 - val_loss: 0.2423
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9466 - loss: 0.2047 - val_accuracy: 0.9659 - val_loss: 0.1712
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9323 - loss: 0.1934 - val_accuracy: 0.9432 - val_loss: 0.1962
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9517 - loss: 0.1562 - val_accuracy: 0.9545 - val_loss: 0.1495
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9499 - loss: 0.1499 - val_accuracy: 0.9659 - val_loss: 0.1292
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9654 - loss: 0.1264 - val_accuracy: 0.9432 - val_loss: 0.1371
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9687 - loss: 0.1210 - val_accuracy: 0.9602 - val_loss: 0.1387
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9806 - loss: 0.0887 - val_accuracy: 0.9602 - val_loss: 0.1367
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9757 - loss: 0.0974 - val_accuracy: 0.9886 - val_loss: 0.0929
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9771 - loss: 0.0793 - val_accuracy: 0.9943 - val_loss: 0.0655
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9806 - loss: 0.0779 - val_accuracy: 0.9773 - val_loss: 0.0903
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9680 - loss: 0.0888 - val_accuracy: 0.9886 - val_loss: 0.0613
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9864 - loss: 0.0549 - val_accuracy: 0.9830 - val_loss: 0.0681
# Epoch 24/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9806 - loss: 0.0622 - val_accuracy: 0.9773 - val_loss: 0.0807
# Epoch 25/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9826 - loss: 0.0550 - val_accuracy: 0.9716 - val_loss: 0.0882
# Epoch 26/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9842 - loss: 0.0556 - val_accuracy: 0.9943 - val_loss: 0.0487
# Epoch 27/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9917 - loss: 0.0436 - val_accuracy: 0.9773 - val_loss: 0.0895
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9845 - loss: 0.0527 - val_accuracy: 0.9886 - val_loss: 0.0475
# Epoch 29/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9903 - loss: 0.0435 - val_accuracy: 0.9830 - val_loss: 0.0748
# Epoch 30/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9870 - loss: 0.0435 - val_accuracy: 0.9943 - val_loss: 0.0740
# Epoch 31/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9790 - loss: 0.0599 - val_accuracy: 0.9943 - val_loss: 0.0492
# Epoch 32/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9933 - loss: 0.0382 - val_accuracy: 0.9773 - val_loss: 0.0525
# Epoch 33/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9934 - loss: 0.0325 - val_accuracy: 0.9773 - val_loss: 0.0708
# Epoch 34/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9959 - loss: 0.0330 - val_accuracy: 0.9886 - val_loss: 0.0327
# Epoch 35/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9936 - loss: 0.0287 - val_accuracy: 0.9886 - val_loss: 0.0529
# Epoch 36/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9906 - loss: 0.0311 - val_accuracy: 0.9943 - val_loss: 0.0497
# Epoch 37/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9876 - loss: 0.0315 - val_accuracy: 0.9830 - val_loss: 0.0432
# Epoch 38/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9938 - loss: 0.0254 - val_accuracy: 0.9830 - val_loss: 0.0439
# Epoch 39/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9928 - loss: 0.0263 - val_accuracy: 0.9773 - val_loss: 0.0686
# Epoch 40/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9875 - loss: 0.0382 - val_accuracy: 0.9943 - val_loss: 0.0411
# Epoch 41/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9779 - loss: 0.0486 - val_accuracy: 0.9886 - val_loss: 0.0426
# Epoch 42/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9922 - loss: 0.0247 - val_accuracy: 0.9943 - val_loss: 0.0240
# Epoch 43/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9928 - loss: 0.0234 - val_accuracy: 0.9659 - val_loss: 0.0694
# Epoch 44/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9794 - loss: 0.0531 - val_accuracy: 0.9886 - val_loss: 0.0331
# Epoch 45/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9982 - loss: 0.0143 - val_accuracy: 0.9886 - val_loss: 0.0318
# Epoch 46/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9957 - loss: 0.0193 - val_accuracy: 0.9886 - val_loss: 0.0276
# Epoch 47/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9894 - loss: 0.0302 - val_accuracy: 0.9886 - val_loss: 0.0397
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9931 - loss: 0.0175 - val_accuracy: 0.9943 - val_loss: 0.0228
# Epoch 49/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9971 - loss: 0.0176 - val_accuracy: 0.9886 - val_loss: 0.0461
# Epoch 50/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9928 - loss: 0.0204 - val_accuracy: 0.9943 - val_loss: 0.0178

# %%
loss, accuracy = model_lstm.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy*100:.2f}%")
models.append("Long Short-Term Memory")
acc.append(accuracy)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9732 - loss: 0.0881
# Test Accuracy: 97.05%

# %%
y_pred_probs = model_lstm.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      0.95      0.97        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      0.94      0.97        17
#            6       0.94      1.00      0.97        17
#            7       1.00      1.00      1.00        14
#            8       0.81      0.91      0.86        23
#            9       0.95      1.00      0.98        20
#           10       0.73      1.00      0.85        11
#           11       1.00      0.95      0.98        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.88      0.93        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        14
#           17       1.00      1.00      1.00        23
#           18       1.00      0.96      0.98        23
#           19       1.00      1.00      1.00        23
#           20       0.88      0.79      0.83        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.97       440
#    macro avg       0.97      0.97      0.97       440
# weighted avg       0.97      0.97      0.97       440

# %%
# model_lstm.save('../models/LSTM.h5')

# %% [markdown]
# # RNN

# %%
le = LabelEncoder()
df['label_encoded'] = le.fit_transform(df['label'])

# %%
X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = to_categorical(df['label_encoded'])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_reshaped = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=42)

# %%
model_rnn = Sequential([
    SimpleRNN(64, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1], activation='softmax
50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9959 - loss: 0.0171 - val_accuracy: 0.9773 - val_loss: 0.0512
# Epoch 36/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9922 - loss: 0.0249 - val_accuracy: 0.9886 - val_loss: 0.0263
# Epoch 37/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9924 - loss: 0.0184 - val_accuracy: 0.9886 - val_loss: 0.0282
# Epoch 38/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9886 - loss: 0.0215 - val_accuracy: 0.9943 - val_loss: 0.0159
# Epoch 39/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9982 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 40/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9977 - loss: 0.0092 - val_accuracy: 0.9886 - val_loss: 0.0195
# Epoch 41/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9907 - loss: 0.0257 - val_accuracy: 0.9830 - val_loss: 0.0304
# Epoch 42/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9952 - loss: 0.0151 - val_accuracy: 0.9773 - val_loss: 0.0468
# Epoch 43/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9943 - val_loss: 0.0123
# Epoch 44/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9976 - loss: 0.0090 - val_accuracy: 0.9943 - val_loss: 0.0178
# Epoch 45/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9976 - loss: 0.0115 - val_accuracy: 0.9886 - val_loss: 0.0800
# Epoch 46/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9933 - loss: 0.0306 - val_accuracy: 0.9886 - val_loss: 0.0199
# Epoch 47/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9981 - loss: 0.0078 - val_accuracy: 0.9886 - val_loss: 0.0325
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9939 - loss: 0.0160 - val_accuracy: 0.9886 - val_loss: 0.0255
# Epoch 49/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9983 - loss: 0.0078 - val_accuracy: 0.9830 - val_loss: 0.0230
# Epoch 50/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9986 - loss: 0.0074 - val_accuracy: 0.9886 - val_loss: 0.0196

# %%
loss, accuracy = model_rnn.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy*100:.2f}%")
models.append("Simple RNN")
acc.append(accuracy)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9790 - loss: 0.0581
# Test Accuracy: 97.95%

# %%
y_pred_probs = model_rnn.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      0.95      0.97        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       0.94      1.00      0.97        17
#            7       1.00      1.00      1.00        14
#            8       0.88      1.00      0.94        23
#            9       0.91      1.00      0.95        20
#           10       0.79      1.00      0.88        11
#           11       1.00      0.95      0.98        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.92      0.96        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        14
#           17       1.00      1.00      1.00        23
#           18       1.00      0.91      0.95        23
#           19       1.00      1.00      1.00        23
#           20       1.00      0.84      0.91        19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.98       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.98      0.98      0.98       440

# %%
# model_rnn.save('../models/RNN.h5')

# %%
plt.figure(figsize=[10, 5], dpi=100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x=acc, y=models, palette='dark')

for i, v in enumerate(acc):
    plt.text(v + 0.005, i, f"{v:.2f}", color='black', va='center')

plt.show()

# %%
accuracy_models = dict(zip(models, acc))
for k, v in accuracy_models.items():
    print (k, '-->', v)
# Out:
# Multi-Layer Perceptron --> 0.9727272987365723
# Long Short-Term Memory --> 0.9727272987365723
# Simple RNN --> 0.9795454740524292

# %%
# preds_mlp = model.predict(X_test[:5])
# predicted_mlp = le.inverse_transform(preds_mlp.argmax(axis=1))
# print("MLP predicted crops:", predicted_mlp)

# %%
custom_input = [[90, 42, 43, 20.87974371, 82.00274423, 6.502985292, 202.9355362]]
custom_input_scaled = scaler.transform(custom_input)

preds_mlp = model_mlp.predict(custom_input_scaled)
predicted_mlp = le.inverse_transform(preds_mlp.argmax(axis=1))

print("MLP predicted crop:", predicted_mlp[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# MLP predicted crop: rice
